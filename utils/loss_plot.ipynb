# %%
import matplotlib.pyplot as plt
import numpy as np

# =============================
# 1. Dữ liệu của bạn
# =============================

train_loss = [
    3.46227687, 3.27177364, 3.16567396, 3.02024287, 2.88381452,
    3.02088895, 2.79219450, 2.87071227, 2.68254095, 2.74494356,
    2.58247437, 2.63430336
]

bleu_scores = {
    "BLEU-1": [0.29632078, 0.30955610, 0.31800274, 0.32237004, 0.32331166,
               0.32918313, 0.32741907, 0.33087921, 0.32806206, 0.33062125,
               0.32937582, 0.32994491],

    "BLEU-2": [0.15731472, 0.17033085, 0.17806857, 0.18319093, 0.18339678,
               0.18952465, 0.18829270, 0.19127242, 0.18938599, 0.19173269,
               0.19024655, 0.19068265],

    "BLEU-3": [0.08712636, 0.09716551, 0.10301532, 0.10707590, 0.10718531,
               0.11195870, 0.11175336, 0.11370375, 0.11244178, 0.11397802,
               0.11268110, 0.11285684],

    "BLEU-4": [0.05064072, 0.05773211, 0.06180971, 0.06481190, 0.06489201,
               0.06830071, 0.06870459, 0.07009837, 0.06897512, 0.07025504,
               0.06899838, 0.06906575]
}

cider_scores = [
    0.27389128, 0.32600577, 0.36018286, 0.38436993, 0.38826907,
    0.40782075, 0.41112043, 0.42626455, 0.41984706, 0.43127861,
    0.42548416, 0.43204719
]

epochs = np.arange(len(train_loss))

# %%
plt.figure(figsize=(8,5))
plt.plot(epochs, train_loss, marker='o')
plt.title("Train Loss theo Epoch")
plt.xlabel("Epoch")
plt.ylabel("Train Loss")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
for key, values in bleu_scores.items():
    plt.plot(epochs, values, marker='o', label=key)

plt.title("BLEU Scores theo Epoch")
plt.xlabel("Epoch")
plt.ylabel("BLEU")
plt.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(epochs, cider_scores, marker='o')
plt.title("CIDEr Score theo Epoch")
plt.xlabel("Epoch")
plt.ylabel("CIDEr")
plt.grid(True)
plt.tight_layout()
plt.show()
